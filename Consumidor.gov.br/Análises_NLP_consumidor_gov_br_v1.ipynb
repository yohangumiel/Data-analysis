# %% [markdown]
# <a href="https://colab.research.google.com/github/yohangumiel/Data-analysis/blob/main/Consumidor.gov.br/An%C3%A1lises_NLP_consumidor_gov_br_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Código desenvolvido para disciplina de Processamento de Linguagem Natural por [Yohan Bonescki Gumiel](https://www.linkedin.com/in/yohan-gumiel-93b33b95/)
#
# #### Análise de n-gramas e contagem de ocorrências de verbos e substantivos para relatos do consumidor.gov.br envolvendo o estado de Minas Gerais
#
# #### Pode ser adaptado para outros arquivos de texto ou planilha (orientações no arquivo)
#
# #### Link de acesso ao material: https://github.com/yohangumiel/Data-analysis

# %% [markdown]
# # DOWNLOAD E INSTALAÇÃO DAS BIBLIOTECAS

# %% [markdown]
# #### NLTK verão 3.4 (para não ter erros nos n-gramas)

# %%
# !pip install nltk==3.4 # necessária a instalação da versão 3.4 para não ter erro nos n-gramas
# Out:
# Collecting nltk==3.4
#   Downloading nltk-3.4.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.6 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.4) (1.15.0)
# Collecting singledispatch
#   Downloading singledispatch-3.7.0-py2.py3-none-any.whl (9.2 kB)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4-py3-none-any.whl size=1436396 sha256=ce44c6a3905e064487d2aad5fc101cc67a85711e5e6e26b9d46b2f7ae7895d8f
#   Stored in directory: /root/.cache/pip/wheels/13/b8/81/2349be11dd144dc7b68ab983b58cd2fae353cdc50bbdeb09d0
# Successfully built nltk
# Installing collected packages: singledispatch, nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed nltk-3.4 singledispatch-3.7.0

# %%
import nltk
print('The nltk version is {}.'.format(nltk.__version__))
# Out:
# The nltk version is 3.4.

# %% [markdown]
# #### Stanza (POS-TAGGER)
#
# #### Página do stanza: https://stanfordnlp.github.io/stanza/

# %%
# !pip install stanza

import stanza
stanza.download('pt')
# Out:
# Collecting stanza
#   Downloading stanza-1.2.3-py3-none-any.whl (342 kB)
#      |████████████████████████████████| 342 kB 5.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.9.0+cu102)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.62.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Installing collected packages: stanza
# Successfully installed stanza-1.2.3
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.2.json:   0%|   …
# 2021-08-28 14:56:07 INFO: Downloading default packages for language: pt (Portuguese)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.2/pt/default.zip:   0%|          | 0.00/209M [00:00<?,…
# 2021-08-28 14:56:46 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
stanza_pt = stanza.Pipeline('pt', tokenize_pretokenized=True, use_gpu= True)
# Out:
# 2021-08-28 14:56:46 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# | pos       | bosque  |
# | lemma     | bosque  |
# | depparse  | bosque  |
# =======================
#
# 2021-08-28 14:56:46 INFO: Use device: gpu
# 2021-08-28 14:56:46 INFO: Loading: tokenize
# 2021-08-28 14:56:46 INFO: Loading: mwt
# 2021-08-28 14:56:56 INFO: Loading: pos
# 2021-08-28 14:56:57 INFO: Loading: lemma
# 2021-08-28 14:56:57 INFO: Loading: depparse
# 2021-08-28 14:56:57 INFO: Done loading processors!

# %% [markdown]
# #### Download das stopwords do NLTK para português (retirada a stopword "não")

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('portuguese'))
stop_words.remove('não')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estamos',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estávamos',
#  'estão',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'nós',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'seu',
#  'seus',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'só',
#  'também',
#  'te',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéramos',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'tém',
#  'tínhamos',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  'à',
#  'às',
#  'é',
#  'éramos'}

# %% [markdown]
# #### Import das bibliotecas

# %%
import os
import glob
import json
import json
import numpy as np
import string
import pandas as pd
import re
from nltk.tokenize import word_tokenize,sent_tokenize
from datetime import datetime
from collections import Counter
from nltk import ngrams
nltk.download('punkt')

pd.set_option('display.max_rows', None) # mostrar todas as linhas do dataframe
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# #### Lista de pontuações a serem retiradas

# %%
remove = string.punctuation
remove
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# # FUNÇÕES/MÉTODOS

# %%
def open_xlsx_folder(folder_path):
    '''
    Leitura de arquivos xlsx (le todos os arquivos em uma pasta)
    Necessário fornecer o caminho da pasta
    '''
    paths = glob.glob(folder_path +"/*.xlsx")
    data = pd.DataFrame()   
    for path in paths:
        df = pd.read_excel(path)
        print('Path: ',path,'\nLen: ',len(df),'\n')
        data = data.append(df)
    data.reset_index(inplace = True)
    return data

def open_xlsx(path):
    '''
    Leitura arquivo xlsx
    '''
    df = pd.read_excel(path)

    return df

def open_txt(path, header):
    '''
    Leitura arquivo txt
    '''
    if header == True:
        df = pd.read_csv(path, delimiter = '\n')
    else:
        df = pd.read_csv(path, delimiter = '\n', header = None)

    return df

def token_preprocess(raw):
    '''
    Etapas de pre-processamento dos tokens para deixar em minúsculo e retirar: caracteres especiais, retirar números, retirar stopwords.
    Alguns passos adicionais para retirar problemas específicos do corpus
    '''  
    raw = [token.lower() for token in raw]
    raw = [''.join(c for c in s if c not in remove) for s in raw]
    raw = [re.sub(r"\d+[.,]?\d*","", s) for s in raw] # regex 
    raw = [s for s in raw if s not in stop_words] # stopwords
    raw = [s for s in raw if 'xx' not in s] # xx de de-identificação de número de telefone XXXX-XXXX ou de e-mail xxxxx@xxxx.com
    raw = [s for s in raw if s != 'r'] # caractere r solto no texto (somente ele)
    raw = [s for s in raw if s != 'h'] # caractere h solto no texto (somente ele)
    raw = [' '.join(s.split()) for s in raw if s]
    string = ' '.join(raw)

    return string.rstrip().lstrip()

def text_preprocess(data):
    '''
    Pre-processamento de todos os textos, fazendo a segmentação de sentenças e tokenização e aplicando a função de token_preprocess (já mencionada acima)
    '''
    processed_data = []
    for text in data:
        text = re.sub("(?i)art[.] ","art ", text)  # erros de tokenização devido a Art. ou art. ou ART. referenciando a artigo, (?i) case-insensitive. EXEMPLO: "Art. 35. Se" fica "Art 35. Se" após processamento ["art","Se"] 
        for sentence in sent_tokenize(text, language = 'portuguese'): 
            tokenized_sentence = word_tokenize(sentence, language='portuguese')
            processed_sentence = token_preprocess(tokenized_sentence)
            if processed_sentence != '':
                processed_data.append(processed_sentence)

    return processed_data


def ngram_analysis(data, ngram, most_common):
    '''
    Análise de ngramas, onde:
    Data = dados
    Ngram = nível dos n-gramas (por exemplo: 2, 3, 4, ..)
    Most_common = quantidade de ngramas mais comuns (por exemplo: 100)
    '''
    
    ngram_counts = [list(ngrams(s.split(), ngram)) for s in data]
    flat_ngram_counts = [item for sublist in ngram_counts for item in sublist]
    ngram_list = Counter(flat_ngram_counts)

    common = ngram_list.most_common(most_common)
    # filename = 'ngram_'+ str(ngram) + '_mostcommon_' + str(most_common) + '_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    # print(filename)

    df_common = pd.DataFrame(common, columns = ['Ngram','Count'])
    # df_common.to_excel(filename,index = True)
    
    
    return df_common


def pos_tagging_analysis(data, most_common):
    '''
    Análise do Postag, onde:
    Data = dados
    Most_common = quantidade de ngramas mais comuns (por exemplo: 100)
    '''

    verbs = []
    verbs_lemma = []
    nouns = []
    nouns_lemma = []
    
    texts = [s for s in data]

    'oi como vai você'   
    for text in texts:
       tokenized_text = word_tokenize(text, language='portuguese')
       if len(tokenized_text) > 0:
           doc =  stanza_pt([tokenized_text])    
           for sent in doc.sentences:
               for word in sent.words:
                   if word.pos == 'VERB':
                       verbs.append(word.text)
                       verbs_lemma.append(word.lemma)
                   elif word.pos == 'NOUN':
                       nouns.append(word.text)
                       nouns_lemma.append(word.lemma)

    counter_verb = Counter(verbs).most_common(most_common)
    # filename = 'counter_verb_mostcommon_' + str(most_common) + '_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    df_verbs = pd.DataFrame(counter_verb, columns = ['Verb','Count'])    
    # df_verbs.to_excel(filename,index = True)
    
    counter_verb_lemma = Counter(verbs_lemma).most_common(most_common)
    # filename = 'counter_verb_lemma_mostcommon_' + str(most_common) + '_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    df_verbs_lemma = pd.DataFrame(counter_verb_lemma, columns = ['Verb_lemma','Count'])
    # df_verbs_lemma.to_excel(filename,index = True)

    
    counter_noun = Counter(nouns).most_common(most_common)
    # filename = 'counter_noun_mostcommon_' + str(most_common) + '_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    df_nouns = pd.DataFrame(counter_noun, columns = ['Noun','Count'])
    # df_noun.to_excel(filename,index = True)
    
    counter_noun_lemma = Counter(nouns_lemma).most_common(most_common)
    # filename = 'counter_noun_lemma_mostcommon_' + str(most_common) + '_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    df_nouns_lemma = pd.DataFrame(counter_noun_lemma, columns = ['Nouns_lemma','Count'])
    # df_noun_lemma.to_excel(filename,index = True)

                          
    return df_verbs, df_verbs_lemma, df_nouns, df_nouns_lemma


def ngram_analysis_first_element(data, first_element_POS, ngram, most_common):
    '''
    Análise do Postag focando na análise do primeiro elemento, onde:
    Data = dados
    first_element_POS = qual o POS do primeiro elemento
    Ngram = nível dos n-gramas (por exemplo: 2, 3, 4, ..)
    Most_common = quantidade de ngramas mais comuns (por exemplo: 100)
    '''
    
    new_data = []
    new_data_lemma = []
    data_concat = []
    data_concat_lemma = []
    for text in data:
        data_concat = []
        data_concat_lemma = []
        if len(text) > 0:        
            doc = stanza_pt([text.split()])              
            for sent in doc.sentences:
                for word in sent.words:
                    concat_word = word.text + '|' + word.pos
                    concat_lemma = word.lemma + '|' + word.pos       
                    data_concat.append(concat_word)
                    data_concat_lemma.append(concat_lemma)
        new_data.append(data_concat)
        new_data_lemma.append(data_concat_lemma)
        
    ngram_counts = [list(ngrams(s,ngram)) for s in new_data]
    ngram_counts_lemma = [list(ngrams(s,ngram)) for s in new_data_lemma]
    
    flat_ngram_counts = [item for sublist in ngram_counts for item in sublist]
    flat_ngram_lemma_counts = [item for sublist in ngram_counts_lemma for item in sublist]
    
    
    flat_ngram_counts_verb = []
    for element in flat_ngram_counts:       
        if first_element_POS in element[0]:
            flat_ngram_counts_verb.append(element)
    
    ngram_list = Counter(flat_ngram_counts_verb)
    common = ngram_list.most_common(most_common)

    
    flat_ngram_counts_lemma_verb = []
    for element in flat_ngram_lemma_counts:       
        if first_element_POS in element[0]:
            flat_ngram_counts_lemma_verb.append(element)
    
    ngram_list = Counter(flat_ngram_counts_verb)
    common = ngram_list.most_common(most_common)
    
    ngram_list_lemma = Counter(flat_ngram_counts_lemma_verb)
    common_lemma = ngram_list_lemma.most_common(most_common)    
    
    
    
    # filename = 'ngram_'+ str(ngram) + '_mostcommon_' + str(most_common) + '_VERB_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    # print(filename)   
    df_first_element = pd.DataFrame(common, columns = ['Ngram','Count'])
    # df_first_element.to_excel(filename,index = True)
    
    
    # filename_lemma = 'ngram_'+ str(ngram) + '_mostcommon_' + str(most_common) + '_VERB_lemma_' + datetime.now().strftime("%Y_%m_%d-%I_%M_%S_%p") + '.xlsx'
    # print(filename_lemma)   
    df_first_element_lemma = pd.DataFrame(common_lemma, columns = ['Ngram','Count'])
    # df_first_element_lemma.to_excel(filename_lemma,index = True)


    return df_first_element, df_first_element_lemma

# %% [markdown]
# # ACESSO AO CONJUNTO DE DADOS DISPONÍVEL NO GITHUB

# %%
# !git clone https://github.com/yohangumiel/Data-analysis.git
# Out:
# Cloning into 'Data-analysis'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 77 (delta 29), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (77/77), done.

# %%
data = open_xlsx('Data-analysis/consumidor-gov-br/relatos_MG_experimento.xlsx')
data.head(20)
# Out:
#                      Nome  ...                                  Status
# 0                Correios  ...                 \n\t\t\t\tNão Resolvido
# 1                 Samsung  ...                 \n\t\t\t\tNão Resolvido
# 2       Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 3       Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 4       Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 5       Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 6             Ame Digital  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 7   Pernambucanas Cartões  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 8   Pernambucanas Cartões  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 9   Pernambucanas Cartões  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 10                  Rappi  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 11       Faculdade Unopar  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 12           Seguros Sura  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 13                    NET  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 14                    NET  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 15         Banco Daycoval  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 16         Banco Daycoval  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 17           Mercado Pago  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 18           Mercado Pago  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 19           Mercado Pago  ...  \n\t\t\t\tNão avaliado pelo consumidor
#
# [20 rows x 7 columns]

# %% [markdown]
# # EXEMPLO DE ACESSO A ARQUIVOS NO FORMATO DE PLANILHA OU TEXTO DO GDRIVE
#
# #### Observação: Retirar os comentários no começo dos códigos para rodar
#
# #### Observação: Necessário que o arquivo esteja na pasta Colab Notebooks (pode alterar a pasta)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_gdrive = open_xlsx('/content/drive/MyDrive/Colab Notebooks/relatos_MG_experimento.xlsx') # exemplo abrindo o mesmo arquivo do github alocado no google drive
data_gdrive.head()
# Out:
#                 Nome  ...                                  Status
# 0           Correios  ...                 \n\t\t\t\tNão Resolvido
# 1            Samsung  ...                 \n\t\t\t\tNão Resolvido
# 2  Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 3  Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
# 4  Vivo - Telefônica  ...  \n\t\t\t\tNão avaliado pelo consumidor
#
# [5 rows x 7 columns]

# %%
data_txt = open_txt('/content/drive/MyDrive/Colab Notebooks/testes.txt', header = False) # exemplo abrindo um arquivo texto no formato sentença 
data_txt.columns = ['texto']
data_txt.head(20)
# Out:
#                                                 texto
# 0   A espada, que estava na casa dele, foi apreend...
# 1      A espada, que estava em casa, foi levada ontem
# 2    O atacante revelou grande decepção com a derrota
# 3    o irmão sofrerá sintomas mais intensos da doença
# 4   A prorrogação poderia abrir a possibilidade de...
# 5              A carta foi escrita em 1913 pelo Duque
# 6       O dono da fazenda viajou para Salvador ontem.
# 7      O dono da fazenda viajou para Salvador, ontem.
# 8      Ontem, o dono da fazenda viajou para Salvador.
# 9                    Ontem, John viajou para Salvador
# 10                    John viajou para Salvador ontem
# 11     Ontem, John viajou para Salvador com seu carro
# 12  Ontem, John viajou para El Salvador com seu carro
# 13  Ontem, John viajou para Buenos Aires com seu c...
# 14          Ontem, John viajou para Salvador de carro
# 15           Ontem à noite, John viajou para Salvador
# 16      John viajou com seu carro para Salvador ontem
# 17            John viajou para Salvador ontem à noite
# 18      John viajou para Salvador com seu carro ontem
# 19               Ele tomou 2 decisões difíceis ontem.

# %% [markdown]
# # RESTRINGE O CONJUNTO DE DADOS AS COLUNAS "RELATO" E "RESPOSTA" E TRANSFORMA EM LISTA

# %%
data_relatos = data['Relato']
list_relatos = data_relatos.values.tolist()

print('Exemplo de relato:\n', list_relatos[0], '\n')
print('Tamanho da lista: ', len(list_relatos))
# Out:
# Exemplo de relato:
#
# 				Boa tarde !
#
# No dia 08/04/2021, por volta das 14:00h fui a agência dos Correios 20307144, localizada em Barbacena-MG, para solicitar um envio de mercadoria para o estado de São Paulo. Ao chegar a agência, havia somente um cliente na minha frente e três funcionários prestando atendimento, até pensei que seria rápido o atendimento, mas fui surpreendido. Além da demora para ser atendido, tive o desprazer de ficar ouvindo as reclamações da funcionária referente ao seus instrumentos de trabalho.
# Como se já não bastasse, fui persuadido por várias vezes para alterar minha forma de envio de PAC para SEDEX, ao recusar a insistência da funcionária percebi um descaso no atendimento e para piorar a situação, tive incluído em meu envio duas tarifas não solicitadas, AVISO DE RECEBIMENTO R$ 6,35  e VALOR DECLARADO R$ 9,59.
# Durante o atendimento foi solicitado meu e-mail e em nenhum momento fui informado que seria para me cobrar algum tipo de serviço. Antes de me direcionar a agência, fiz a simulação de envio através do site dos Correios e o valor não passaria de R$ 30,00 mas ao realizar  pagamento o valor total foi de R$ 45,34.
#
# A disposição!
#
# Tamanho da lista:  10001

# %%
data_respostas = data['Resposta']
list_respostas = data_respostas.values.tolist()

print('Exemplo de reposta:\n', list_respostas[1], '\n')
print('Tamanho da lista: ', len(list_respostas))
# Out:
# Exemplo de reposta:
#
# 				Caro cliente,
#
#
#
# Conforme contato realizado através desta plataforma, os esclarecimentos necessários foram prestados. Além disso, está disponível maiores detalhes no histórico de seu protocolo. Qualquer dúvida estamos à disposição em nosso canal de atendimento no telefone informado pelo nosso especialista.
#
#
#
# Atenciosamente,
# Samsung Eletrônica da Amazônia
#
# Tamanho da lista:  10001

# %% [markdown]
# # EXEMPLO DO PRE-PROCESSAMENTO DO TEXTO

# %%
data_relatos_processado = text_preprocess(list_relatos)

data_relatos_processado[0:100]
# Out:
# ['boa tarde',
#  'dia volta agência correios localizada barbacenamg solicitar envio mercadoria estado paulo',
#  'chegar agência havia somente cliente frente três funcionários prestando atendimento pensei rápido atendimento surpreendido',
#  'além demora ser atendido desprazer ficar ouvindo reclamações funcionária referente instrumentos trabalho',
#  'não bastasse persuadido várias vezes alterar forma envio pac sedex recusar insistência funcionária percebi descaso atendimento piorar situação incluído envio duas tarifas não solicitadas aviso recebimento valor declarado',
#  'durante atendimento solicitado email nenhum momento informado cobrar algum tipo serviço',
#  'antes direcionar agência fiz simulação envio através site correios valor não passaria realizar pagamento valor total',
#  'disposição',
#  'realizar ultima atualização android segunda vez aparelho travou tela i belive in your galaxy não sai disso',
#  'tentando reiniciar forcadamente nada resolve',
#  'havia acontecido atualização android perdi tudo aparelho',
#  'dessa vez não vou querer apenas conserto sim aparelho novo garante cdc caso defeito fabrica recorrente vou processar samsung pois vai ser segunda vez perco tudo',
#  'absurdo',
#  'segue anexo nota fiscal recibo autorizada primeira vez ocorreu',
#  'amanhã dia estarei indo autorizada novamente',
#  'contatar empresa solicitei ª via contas detalhadas plano porém recebi fatura simplificada alguns meses',
#  'fiz reclamação anteriormente respeito débito aberto serasa atendente informou prazo dias resolvido passaram muitos dias débito ainda continua aberto',
#  'tentei entrar app vivo fazer pagamento conta atraso número cancelado novamente tentei contato peço segunda via diz ocorreu erro sistema não pagar fatura não código barras',
#  'solicitei vivo plano número valor',
#  'acontece alguns meses alteraram valor antes comunicarem',
#  'entrei contato posteriormente reclamação consumidorgov julho retornaram valor realmente contratado',
#  'acontece novamente cobrando valor acima contratado solicitei então cancelamento plano sucesso',
#  'não param ligar oferecer produtos condominio onde moro',
#  'residencial cristina cnpj',
#  'não sindica não têm direito ligarem parar oferecer produtos',
#  'dia fiz pedido número site submarinocom utilizando método pagamento ame digital',
#  'itens tapete yoga pilates eva – muvin vendido cashpeg valor entrega',
#  'dia recebi mensagem submarinocom parceiro ainda não havia confirmado havia enviado pedido',
#  'dia aberta solicitação cancelamento s produto s',
#  'dia recebi mensagem “ solicitação cancelamento s produto s abaixo pedido finalizada',
#  'reembolso solicitado administradora cartão crédito estará disponível próxima fatura seguinte acordo regras administradora cartão ” desde então entrei contato vendedor algumas vezes ano passado alertando não localizei reembolso faturas',
#  'tentei contato algumas vezes vendedor recebendo sempre resposta “ boa tarde rafael',
#  'ame digital acionado referente reembolso pedido tapete yoga eva cm x cm x cm muvin',
#  'favor contacte central atendimento telefone informei ticket',
#  'vou finalizar protocolo atendimento espero ter colaborado alguma maneira alcançado expectativas atendimento ” sempre imensa dificuldade obter contato serviço ame digital através chat aplicativo modo hoje não recebi resposta equipe',
#  'procurado operadora dia devido não baixa fatura paga dia vencimento',
#  'após data gerado cobranças duplicadas valor pago taxas multas bem notificação negativado cpf serasa',
#  'fatura vencida devido problemas financeiras necessário realizar parcelamento',
#  'realizado atrás chat app dia',
#  'onde parcelei fatura x pagamento',
#  'fiz transferência via pix valor conta digital pernambucanas efetuar pagamento valor parcela entrada',
#  'porém tentar finalizar pagamento informa senha errada',
#  'acionei atendimento via whatsapp protocolo onde moça informou senha cartão conta ativos',
#  'criam conta não informa cliente usala descobre cartões diferentes precisa ir loja gerar ativar lojas fechadas plena pandemia',
#  'entrei contato via telefone solicitando envio senha duas vezes',
#  'dois atendentes falaram ate horas receberia senha via sms',
#  'senha não chegou após hs',
#  'solicito empresa resolver situação pois recebi comunicado serasa pernambucanas noticiou negativação nome junto órgão',
#  'divida mês vencida negociei loja não colabora pagar',
#  'segue anexo negociação via chat dia',
#  'boa noite',
#  'dia março entrei contato sac pernanbucas resolver situação fatura sido pagas dai dia tirei outra fatura dai veio muita multa atraso juros atendente disse pra pagar fatura veio paguei deu protocolo falou pra entrar email fiz exatamente falou mandei email mandei numero protocolo anexei fatura paga disse pra aguardar dia ninguém entrou contato comigo agora tirei outra fatura veio estorno hoje dia recebi ligação dizendo faturas pagar fevereiro outra março segue anexo segunda feira fecha outra fatura vem juros multas faturas fevereiro março desempregada não pagar cobrando sendo paguei',
#  'mês janeiro diagnosticado covid entrei contato time rappi avisar doente ausentar trabalho algum tempo curasse recebi valor reais rappi referente fundo covid porém desativaram conta hoje após quase meses não habilitadaram novamente',
#  'não mim passada todas informações correta relação segunda graduação informado pagar taxa realizar analise histórico não mim passado não contrato',
#  'fiz abertura sinistro perante empresa citada furto bicicleta segurada perante seguradora juntamente seguro residencial',
#  'sinistro aberto data ocorreu furto',
#  'seguradora informou prazo após abertura sinistro dar seguimento processo',
#  'liguei várias vezes seguradora através telefone sempre falaram iam encaminhar analista sinistro presente data não retorno mencionada analista',
#  'data hoje entrei contato net pois três meses consecutivos vêm sendo cobrado serviço fatura não contratei mensalidade assistência técnica valor informado serviço ativo desde abril ano passado porém serviço começou ser cobrado fatura três meses desde verifiquei ocorrido ligo todos meses qdo chega fatura peço contestação cancelamento momento algum fiz solicitação ai informado cancelamento feito mês seguinte vem cobrança novamente',
#  'hoje contestação feita fiquei minutos ligação ser informado espearar horas pro setor responsável entrar contato ver possibilidade contestação',
#  'peço contato número falar josiane esposa pois não posso atender telefone horario trabalho',
#  'conforme reclamações anteriores requeiro encaminhado faturas desde abril análise',
#  'banco daycovall desconta parcelas consignado duas vezes mês abril fonte governo mgseplagcontracheque conta corrente banco brasil ag',
#  'ct',
#  'anelito pereira oliveira',
#  'assim banco daycovall mantém restrição nome cadastro credores scr banco central lista consumidores deram prejuízo sistema financeiro',
#  'reclamei banco nesta plataforma',
#  'banco esclareceu não atraso pagamento empréstimo propôs quitação valor ainda devido',
#  'banco indicou telefone manifestasse sobre interesse quitação empréstimo',
#  'tentei inúmeras vezes falar nesse telefone não atendido',
#  'contrapartida banco feito contato comigo via whatsapp propondo refinanciamento empréstimo situação receberia troco cerca',
#  'absurdo',
#  'venho meio desta reclamação pedir encaminhem email contrato financiamento veicular veiculo toyota corolla ano placa hfp valor parcela analise valores contidos',
#  'agradeço grandemente aguardo retorno',
#  'maquininha mercado pago não descontaram nada dinheiro maquininha some',
#  'sempre realizei jogos lotéricos online nunca problemas pagamento via cartão crédito porém dia tente realizar pagamento jogos dava mensagem compra não sendo autorizada tentei todos cartões crédito cartões total sempre mesma mensagem não autorizados liguei atendimento cartões obtive informações todos ok limites problema não cartões',
#  'segundafeira liguei caixa loterias onde informado problema meio pagamento nesse caso mercado pago entrei contato mercado pago email dia porém respostas sempre automáticas não resolvem nada',
#  'enviei pagamentos mercado pago nome rafael vieira santos cpf compra computador usado mercado livre',
#  'desvinculo produto pagamento não sei vendedor sumiu após dois dias não enviou produto',
#  'pouco tempo mercado livre primeira venda problema',
#  'mercado livre suspendeu conta motivos',
#  'preciso resolvam problema rápido possível',
#  'indignada plataforma',
#  'olá boa tarde tudo bem',
#  'criar conta mercado livre segui todos passos enviei selfie fotos documentos aparece mensagem conta suspensa',
#  'lembro usei conta não consegui entrar época não recordo motivo',
#  'agora anos aparece conta suspensa ideia motivo',
#  'recorro canal pedir obséquio façam análise conta re ativada poder utilizar eou informem motivo aparecer suspensa nunca cometi nenhuma ilicitude',
#  'virtude pandemia desempregado filhos pequenos criar',
#  'mercado livre ótima ferramenta divulgar produtos artesanais conseguir arcar aluguel outras coisas',
#  'porque vender rua não posso devido pandemia risco contágio',
#  'portanto internet ideal principalmente mercado livre bem quisto bem conhecido boa parte população',
#  'peço encarecidamente analisem carinho solicitação',
#  'quero vender',
#  'não possível menos informe aconteceu fato conta ser suspensa pois podem ver histórico nunca apliquei golpe ninguém nunca nenhum problema ninguém',
#  'certo ser atendido fico desde agradecido',
#  'grande abraço todos bom feriado ótimo resto semana',
#  'cuidem todos afinal todos barco \uf04a respeitosamente thiago',
#  'hoje conta indevidamente suspensa motivo algum simplesmente suspenderam dinheirocede venda lá preso não consigo enviar produtos clientes fica situação',
#  'devido pandemia solicitei cancelamento reembolso voo reserva bdpcm dia']

# %%
data_respostas_processado = text_preprocess(list_respostas)

data_respostas_processado[0:100]
# Out:
# ['prezado cliente possamos verificar ocorrido tomar devidas providências necessitamos informações adicionais',
#  'caso manifestação envolva objeto postal registrado solicitamos acessar endereço http appscorreioscombrfaleconoscoappcadastroreclamacaoindexphp codigondyz selecionar opção inconformidade entrega remessaobjeto postal',
#  'caro cliente conforme contato realizado através desta plataforma esclarecimentos necessários prestados',
#  'além disso disponível maiores detalhes histórico protocolo',
#  'qualquer dúvida disposição canal atendimento telefone informado especialista',
#  'atenciosamente samsung eletrônica amazônia',
#  'prezada sra vitoria realizamos tentativa contato dia porém não obtivemos sucesso',
#  'desta forma segue carta anexa informações providências tomadas relação questionamento juntamente análise operadora',
#  'disposição quaisquer esclarecimentos através email inserido carta resposta seguintes canais site wwwvivocombr sms encaminhando mensagem',
#  'caso alguma dúvida discordância questionamento gentileza utilizar botão “ interagir fornecedor ” antes executar qualquer ação',
#  'favor visualizar campo “ anexos ”',
#  'obs',
#  'caso consulta celular poderá não ser disponibilizado carta anexa pois depende funcionalidade cada aparelho',
#  'desta forma orientamos acesso realizado computadortablet',
#  'atenciosamente órgão defesa consumidor – telefônica vivo',
#  'prezada sra juliana realizamos tentativa contato dia porém não obtivemos sucesso',
#  'desta forma segue carta anexa informações providências tomadas relação questionamento juntamente análise operadora',
#  'disposição quaisquer esclarecimentos através email inserido carta resposta seguintes canais site wwwvivocombr sms encaminhando mensagem',
#  'caso alguma dúvida discordância questionamento gentileza utilizar botão “ interagir fornecedor ” antes executar qualquer ação',
#  'favor visualizar campo “ anexos ”',
#  'obs',
#  'caso consulta celular poderá não ser disponibilizado carta anexa pois depende funcionalidade cada aparelho',
#  'desta forma orientamos acesso realizado computadortablet',
#  'atenciosamente órgão defesa consumidor – telefônica vivo',
#  'contatamos responsável manifestação dia ficou ciente informações providências tomadas relação questionamento',
#  'disposição quaisquer esclarecimentos sobre demanda através email informado carta anexo demais assuntos favor contatar seguintes canais site wwwvivocombr sms encaminhando mensagem',
#  'caso alguma dúvida discordância questionamento gentileza utilizar botão “ interagir fornecedor ” antes executar qualquer ação',
#  'favor visualizar campo “ anexos ”',
#  'obs',
#  'caso consulta celular poderá não ser visualizada carta anexa pois depende funcionalidade cada aparelho',
#  'desta forma orientamos acesso realizado computadortablet',
#  'atenciosamente órgão defesa consumidor – telefônica vivo',
#  'prezada sra brenda segue carta anexo informações providências tomadas relação questionamento juntamente análiseproposta operadora',
#  'disposição quaisquer esclarecimentos através email contido carta resposta',
#  'caso alguma dúvida discordância questionamento gentileza utilizar botão “ interagir fornecedor ” antes executar qualquer ação',
#  'favor visualizar campo “ anexos ”',
#  'obs',
#  'caso consulta celular poderá não ser disponibilizado carta anexa pois depende funcionalidade cada aparelho',
#  'desta forma orientamos acesso realizado computadortablet',
#  'atenciosamente órgão defesa consumidor – telefônica vivo',
#  'bom dia rafael',
#  'vai',
#  'não palavras desculpar',
#  'sabemos importância problema correndo atrás resolvermos quanto antes',
#  'aguardando apenas confirmação adquirente conclusão valor fatura',
#  'assim confirmarem estorno notificaremos imediato possamos validar juntos',
#  'não desistiremos tudo resolvido',
#  'agradecemos desde',
#  'atenciosamente thamis atendimento especial consumidorgov',
#  'olá lazara recebemos manifestação informamos após analise pagamento consta processado sistema',
#  'sendo assim não possui negativação cpf',
#  'atenciosamente equipe mídias sociais pernambucanas mídias sociais pernambucanas loja app site família',
#  'sempre precisar falar conosco utilize canais oficiais whats chat aplicativo cartão pernambucanas central atendimento',
#  'olá cristiano recebemos manifestação informamos após analise sistema necessário efetue transferência conta digital efetuar pagamento fatura vigente',
#  'atenciosamente equipe mídias sociais pernambucanas mídias sociais pernambucanas loja app site família',
#  'sempre precisar falar conosco utilize canais oficiais whats chat aplicativo cartão pernambucanas central atendimento',
#  'olá marcilene recebemos manifestação informamos realizamos ajustes valores cobrado indevido sistema cobrado fatura valor estará evidente próxima fatura',
#  'atenciosamente equipe mídias sociais pernambucanas mídias sociais pernambucanas loja app site família',
#  'sempre precisar falar conosco utilize canais oficiais whats chat aplicativo cartão pernambucanas central atendimento',
#  'olá prezado',
#  'dando continuidade tratativa via email',
#  'caso dúvidas seguiremos disposição',
#  'atenciosamente equipe rappi',
#  'olá everaldo boa tarde referente reclamação formalizada meio deste canal informamos detalhes tratativa instituição inseridos área interação consumidor conter informações dados sigilosos',
#  'permanecemos disposição demais esclarecimentos',
#  'atenciosamente central relacionamento aluno unopar',
#  'prezado senhor boa tarde tudo bem',
#  'informamos resposta vossa reclamação enviada email cadastrado presente plataforma',
#  'agradecemos vosso contato ficamos disposição fizer necessário',
#  'qualquer problema gentileza volte contatar',
#  'atenciosamente ouvidoria seguros sura',
#  'prezado sr',
#  'nelio atenção reclamação verifique anexo lado opção detalhes carta resposta contendo todas informações tratamento',
#  'observação caso consulta celular poderá não ser disponibilizado carta anexo pois depende funcionalidade cada aparelho',
#  'dessa forma caso não consiga visualizar anexo através aparelho celular orientamos acessar resposta através computadortablet',
#  'qualquer dificuldade visualizar anexo dúvida solução apresentada poderá contatar utilizando opção “ interagir fornecedor ” ainda através canais exclusivos informados carta anexo',
#  'atenciosamente aline',
#  'prezado sr',
#  'joão atenção reclamação verifique anexo lado opção detalhes carta resposta contendo todas informações tratamento',
#  'observação caso consulta celular poderá não ser disponibilizado carta anexo pois depende funcionalidade cada aparelho',
#  'dessa forma caso não consiga visualizar anexo através aparelho celular orientamos acessar resposta através computadortablet',
#  'qualquer dificuldade visualizar anexo dúvida solução apresentada poderá contatar utilizando opção “ interagir fornecedor ” ainda através canais exclusivos informados carta anexo',
#  'atenciosamente aline',
#  'prezado diante reclamação registrada meio plataforma “ consumidor',
#  'gov ” investimos todos esforços solução tema abordado sendo realizada análise pormenorizada cuja conclusão disponibilizada senhor meio campo “ anexo ” obediência artigo º xii constituição federal lei complementar nº disciplinam sigilo operações instituições financeiras bem termos uso',
#  'aproveitamos oportunidade divulgar atendimento daycoval internet https wwwdaycovalcombrinstitucionalcentralatendimento',
#  'nesta página poderá registrar solicitações esclarecer dúvidas preferir poderá contatar através telefones central serviços sac – reclamações sugestão elogios deficientes auditivos ainda caso não manifestação atendida satisfatoriamente acione ouvidoria http wwwdaycovalcombrdefaultasp areaouvidoria telefone',
#  'prezado diante reclamação registrada meio plataforma “ consumidor',
#  'gov ” investimos todos esforços solução tema abordado sendo realizada análise pormenorizada cuja conclusão disponibilizada senhor meio campo “ anexo ” obediência artigo º xii constituição federal lei complementar nº disciplinam sigilo operações instituições financeiras bem termos uso',
#  'aproveitamos oportunidade divulgar atendimento daycoval internet https wwwdaycovalcombrinstitucionalcentralatendimento',
#  'nesta página poderá registrar solicitações esclarecer dúvidas preferir poderá contatar através telefones central serviços sac – reclamações sugestão elogios deficientes auditivos ainda caso não manifestação atendida satisfatoriamente acione ouvidoria http wwwdaycovalcombrdefaultasp areaouvidoria telefone',
#  'olá graziele',
#  'agradeço aguardar resposta',
#  'enviamos detalhes sobre solicitação interação anterior',
#  'qualquer outra dúvida sintase vontade entrar contato equipe atendimento através deste link https wwwmercadopagocombrajuda',
#  'equipe mercado pago',
#  'olá sebastião vai',
#  'antes nada grupo mercado livre agradecemos contato pedimos desculpas eventuais transtornos causados',
#  'esperamos continuar contando preferência',
#  'conferir resposta pedimos clique anexo']

# %% [markdown]
# # ANÁLISE DE N-GRAMAS (1, 2 e 3) RELATOS

# %%
ngram = 1
df_unigram = ngram_analysis(data_relatos_processado, ngram, 100)
df_unigram.head(20)
# Out:
#               Ngram  Count
# 0            (não,)  20831
# 1            (dia,)   7651
# 2          (valor,)   7305
# 3        (contato,)   4829
# 4          (conta,)   4145
# 5        (empresa,)   4034
# 6           (pois,)   3670
# 7         (compra,)   3420
# 8         (cartão,)   2881
# 9          (banco,)   2877
# 10          (dias,)   2531
# 11       (produto,)   2469
# 12         (sendo,)   2458
# 13  (cancelamento,)   2444
# 14           (fiz,)   2361
# 15          (site,)   2316
# 16         (porém,)   2278
# 17     (pagamento,)   2272
# 18      (problema,)   2258
# 19        (pedido,)   2220

# %%
ngram = 2
df_bigram = ngram_analysis(data_relatos_processado, ngram, 100)
df_bigram.head(20)
# Out:
#                     Ngram  Count
# 0       (entrei, contato)   1618
# 1       (cartão, crédito)    900
# 2          (não, consigo)    794
# 3             (pois, não)    620
# 4       (entrar, contato)    619
# 5            (boa, tarde)    565
# 6         (pesquisa, cpf)    540
# 7           (não, recebi)    476
# 8      (contato, empresa)    450
# 9              (bom, dia)    431
# 10     (realizei, compra)    431
# 11          (fiz, compra)    404
# 12          (havia, sido)    393
# 13   (resolver, problema)    382
# 14               (art, º)    379
# 15           (porém, não)    367
# 16        (recebi, email)    367
# 17  (histórico, pesquisa)    365
# 18          (dias, úteis)    362
# 19           (ainda, não)    358

# %%
ngram = 3
df_trigram = ngram_analysis(data_relatos_processado, ngram, 100)
df_trigram.head(20)
# Out:
#                                     Ngram  Count
# 0              (histórico, pesquisa, cpf)    359
# 1                           (art, º, lei)    329
# 2           (tratamento, dados, pessoais)    179
# 3        (qualquer, consentimento, parte)    176
# 4             (parte, coleta, tratamento)    176
# 5             (coleta, tratamento, dados)    176
# 6                      (cpf, base, dados)    176
# 7             (não, significa, restrição)    176
# 8          (consentimento, parte, coleta)    175
# 9       (carece, consentimento, expresso)    175
# 10       (consentimento, expresso, forma)    175
# 11                  (pesquisa, cpf, base)    174
# 12          (considerando, não, qualquer)    174
# 13                  (cpf, não, significa)    174
# 14         (não, qualquer, consentimento)    173
# 15                   (pesquisa, cpf, não)    173
# 16  (consequências, requerimento, abaixo)    173
# 17            (base, dados, administrada)    172
# 18      (requerimento, abaixo, formulado)    172
# 19         (ciência, histórico, pesquisa)    172

# %% [markdown]
# # ANÁLISE DE VERBOS E SUBSTANTIVOS MAIS COMUNS
#
# #### Observação: foram utilizados somente os 1000 primeiros textos para ter um menor tempo de processamento

# %%
df_verbs, df_verbs_lemma, df_nouns, df_nouns_lemma = pos_tagging_analysis(data_relatos_processado[0:1000], 100)

# %%
df_verbs.head(20)
# Out:
#          Verb  Count
# 0       conta     56
# 1         fiz     51
# 2      recebi     45
# 3      entrei     41
# 4       fazer     37
# 5      pedido     36
# 6   solicitei     31
# 7       feito     31
# 8       disse     30
# 9    informou     27
# 10  informado     26
# 11     liguei     26
# 12     entrar     24
# 13     tentei     23
# 14      pagar     23
# 15       pago     23
# 16     paguei     22
# 17       veio     21
# 18   realizar     20
# 19       pedi     19

# %%
df_verbs_lemma.head(10)
# Out:
#   Verb_lemma  Count
# 0      fazer    168
# 1   informar    105
# 2      pedir     95
# 3      pagar     90
# 4    receber     85
# 5  solicitar     84
# 6     entrar     80
# 7        vir     59
# 8     contar     57
# 9      dizer     57

# %%
df_nouns.head(20)
# Out:
#             Noun  Count
# 0            dia    160
# 1          valor    148
# 2        contato     97
# 3        empresa     71
# 4      pagamento     58
# 5            mês     55
# 6        produto     51
# 7         fatura     48
# 8           dias     47
# 9   cancelamento     47
# 10        cartão     46
# 11          site     43
# 12      problema     41
# 13         conta     40
# 14         plano     38
# 15         email     37
# 16    reclamação     36
# 17        compra     36
# 18       serviço     35
# 19         banco     35

# %%
df_nouns_lemma.head(20)
# Out:
#      Nouns_lemma  Count
# 0            dia    207
# 1          valor    178
# 2        contato    100
# 3            mês     85
# 4        empresa     72
# 5        produto     70
# 6      pagamento     61
# 7         fatura     59
# 8         cartão     55
# 9          conta     52
# 10           vez     48
# 11      problema     48
# 12       ligação     48
# 13        compra     48
# 14  cancelamento     47
# 15      cobrança     47
# 16         email     46
# 17           ano     44
# 18          site     43
# 19       serviço     43

# %% [markdown]
# # ANÁLISE DO PRIMEIRO ELEMENTO SENDO UM VERBO E ANÁLISES ADICIONAIS

# %%
ngram = 2
first_element = 'VERB'
df_bigram_first_element, df_bigram_first_element_lemma = ngram_analysis_first_element(data_relatos_processado[0:1000], first_element, ngram, 100)

# %%
df_bigram_first_element.head(20)
# Out:
#                               Ngram  Count
# 0       (entrei|VERB, contato|NOUN)     35
# 1       (entrar|VERB, contato|NOUN)     18
# 2   (exigir|VERB, cumprimento|NOUN)      7
# 3    (forçado|VERB, obrigação|NOUN)      7
# 4      (aguardo|VERB, retorno|NOUN)      6
# 5             (disse|VERB, não|ADV)      6
# 6    (resolver|VERB, problema|NOUN)      6
# 7       (cabe|VERB, reembolso|NOUN)      6
# 8       (tentei|VERB, contato|NOUN)      5
# 9         (informado|VERB, não|ADV)      5
# 10            (data|VERB, hoje|ADV)      5
# 11     (tentar|VERB, resolver|VERB)      5
# 12           (feito|VERB, dia|NOUN)      5
# 13        (pedido|VERB, feito|VERB)      5
# 14      (realizar|VERB, troca|NOUN)      5
# 15      (efetuei|VERB, compra|NOUN)      5
# 16       (recebi|VERB, fatura|NOUN)      4
# 17      (fiz|VERB, reclamação|NOUN)      4
# 18       (tentei|VERB, entrar|VERB)      4
# 19        (pagar|VERB, fatura|NOUN)      4

# %%
df_bigram_first_element_lemma.head(20)
# Out:
#                               Ngram  Count
# 0       (entrar|VERB, contato|NOUN)     65
# 1          (informar|VERB, não|ADV)     17
# 2             (dizer|VERB, não|ADV)     11
# 3    (resolver|VERB, problema|NOUN)      8
# 4      (receber|VERB, produto|NOUN)      8
# 5        (fazer|VERB, contato|NOUN)      7
# 6             (poder|VERB, ser|AUX)      7
# 7          (pagar|VERB, valor|NOUN)      7
# 8   (exigir|VERB, cumprimento|NOUN)      7
# 9     (forçar|VERB, obrigação|NOUN)      7
# 10     (realizar|VERB, compra|NOUN)      7
# 11        (pagar|VERB, fatura|NOUN)      6
# 12    (receber|VERB, mensagem|NOUN)      6
# 13       (aguar|VERB, retorno|NOUN)      6
# 14        (fazer|VERB, compra|NOUN)      6
# 15    (abrir|VERB, reclamação|NOUN)      6
# 16         (fazer|VERB, troca|NOUN)      6
# 17            (dever|VERB, ser|AUX)      6
# 18     (conseguir|VERB, falar|VERB)      6
# 19       (receber|VERB, nenhum|DET)      6

# %%
ngram = 3
first_element = 'VERB'
df_trigram_first_element, df_trigram_first_element_lemma = ngram_analysis_first_element(data_relatos_processado[0:1000], first_element, ngram, 100)

# %%
df_trigram_first_element.head(20)
# Out:
#                                              Ngram  Count
# 0    (exigir|VERB, cumprimento|NOUN, forçado|VERB)      7
# 1       (entrei|VERB, contato|NOUN, novamente|ADV)      5
# 2     (recusar|VERB, cumprimento|NOUN, oferta|ADJ)      4
# 3   (poderá|VERB, alternativamente|ADV, livre|ADJ)      4
# 4      (forçado|VERB, obrigação|NOUN, termos|NOUN)      4
# 5      (tentar|VERB, resolver|VERB, problema|NOUN)      4
# 6         (efetuei|VERB, compra|NOUN, pedido|VERB)      4
# 7              (pedido|VERB, feito|VERB, dia|NOUN)      4
# 8     (acontece|VERB, pedido|NOUN, cancelado|VERB)      4
# 9          (quero|VERB, dinheiro|NOUN, volta|VERB)      3
# 10        (tentei|VERB, entrar|VERB, contato|NOUN)      3
# 11       (cabe|VERB, reembolso|NOUN, integral|ADJ)      3
# 12          (pedido|VERB, valor|NOUN, pedido|VERB)      3
# 13         (pedido|VERB, unidades|NOUN, item|NOUN)      3
# 14              (feito|VERB, dia|NOUN, prazo|NOUN)      3
# 15            (entrega|VERB, dias|NOUN, uteis|ADJ)      3
# 16         (cancelado|VERB, venho|VERB, meio|NOUN)      3
# 17              (venho|VERB, meio|NOUN, dessa|DET)      3
# 18      (resolver|VERB, problema|NOUN, forma|NOUN)      3
# 19     (receber|VERB, produtos|NOUN, comprei|VERB)      3

# %%
df_trigram_first_element_lemma.head(20)
# Out:
#                                             Ngram  Count
# 0    (exigir|VERB, cumprimento|NOUN, forçar|VERB)      7
# 1      (entrar|VERB, contato|NOUN, novamente|ADV)      5
# 2       (querer|VERB, dinheiro|NOUN, voltar|VERB)      4
# 3            (informar|VERB, não|ADV, haver|VERB)      4
# 4        (tentar|VERB, entrar|VERB, contato|NOUN)      4
# 5    (recusar|VERB, cumprimento|NOUN, oferta|ADJ)      4
# 6   (poder|VERB, alternativamente|ADV, livre|ADJ)      4
# 7      (forçar|VERB, obrigação|NOUN, termos|NOUN)      4
# 8     (tentar|VERB, resolver|VERB, problema|NOUN)      4
# 9          (efetar|VERB, compra|NOUN, pedir|VERB)      4
# 10             (pedir|VERB, fazer|VERB, dia|NOUN)      4
# 11   (acontecer|VERB, pedido|NOUN, cancelar|VERB)      4
# 12              (dizer|VERB, não|ADV, poder|VERB)      3
# 13     (contratar|VERB, nenhum|DET, serviço|NOUN)      3
# 14     (caber|VERB, reembolso|NOUN, integral|ADJ)      3
# 15           (pedir|VERB, valor|NOUN, pedir|VERB)      3
# 16          (pedir|VERB, unidade|NOUN, item|NOUN)      3
# 17             (fazer|VERB, dia|NOUN, prazo|NOUN)      3
# 18            (entregar|VERB, dia|NOUN, util|ADJ)      3
# 19           (cancelar|VERB, vir|VERB, meio|NOUN)      3

# %% [markdown]
# # CÓDIGO PARA WORDCLOUD
#
# #### Observação: Adaptado para os dados do consumidor.gov.br

# %%
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
import matplotlib.pyplot as plt
from PIL import Image

# %%
def word_cloud_colored(lst_text, fig_img, color = 'white', height = 400, width = 800, max_words = 2000, colormap = None, size_X = 20, size_Y = 20):

    str_text=" ".join(lst_text)
    figure_mask = np.array(Image.open(fig_img))
    
    
    wordcloud=WordCloud(background_color = color, mask = figure_mask, max_words = max_words, max_font_size = 90, colormap = colormap, height = height, width = width).generate(str_text)

    X = size_X/2.54
    Y = size_Y/2.25

    # image_colors = ImageColorGenerator(figure_mask)
    fig = plt.figure(figsize = [X, Y])
    plt.imshow(wordcloud, interpolation = "bilinear") #.recolor(color_func = image_colors)
    plt.axis("off")
    plt.show()



def word_cloud(lst_text, color = 'white', height = 400, width = 800, max_words = 2000, colormap = None, size_X = 20, size_Y = 20):

        
    str_text=" ".join(lst_text)


    wordcloud=WordCloud(background_color = color, max_words = max_words, max_font_size = 90, colormap = colormap, height = height, width = width).generate(str_text)

    

    X = size_X/2.54
    Y = size_Y/2.25

    fig = plt.figure(figsize = [X, Y])
    plt.imshow(wordcloud, interpolation = "bilinear")
    plt.axis("off")
    plt.box(False)
    plt.show()

# %%
# colormaps: https://matplotlib.org/stable/tutorials/colors/colormaps.html
# colors: https://matplotlib.org/stable/gallery/color/named_colors.html

background_color = 'black'
cmap = 'prism'
str_tweets=word_cloud(data_relatos_processado, color = background_color, colormap = cmap, max_words = 200, size_X = 50, size_Y = 50)

# %% [markdown]
# #### Teste com Wordcloud com imagem de fundo

# %%
img= 'Data-analysis/consumidor-gov-br/logo_consumidor.gov.br.png'
background_color='black'
cmap = 'Greens'
word_cloud_colored(data_relatos_processado, fig_img = img, color = background_color, colormap = cmap, size_X = 30, size_Y = 30)
